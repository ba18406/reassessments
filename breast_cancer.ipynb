# %% [markdown]
# <a href="https://colab.research.google.com/github/ba18406/reassessments/blob/master/breast_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Set our RNG seed for reproducibility.
RANDOM_STATE_SEED = 1
np.random.seed(RANDOM_STATE_SEED)

# %%
#Loading the iris dataset. Performing principal component analysis on iris dataset. Then visualizing the results of principal component analysis.

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA
from sklearn.datasets import load_breast_cancer

# loading the breast_cancer dataset
breast_cancer = load_breast_cancer()

# visualizing the classes
with plt.style.context('seaborn-white'):
    plt.figure(figsize=(7, 7))
    pca = PCA(n_components=2).fit_transform(breast_cancer['data'])                   
    plt.scatter(x=pca[:, 0], y=pca[:, 1], c=breast_cancer['target'], cmap='viridis', s=50)
    plt.title('The breast_cancer dataset')
    plt.show()

# %%
#Making a pool of predictors and target variables from the original dataset. This is later used by ModAL for active learning.
from copy import deepcopy

# generate the pool
X_pool = deepcopy(breast_cancer['data'])
y_pool = deepcopy(breast_cancer['target'])

# %%
pip install modAL
# Out:
# Requirement already satisfied: modAL in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.6/dist-packages (from modAL) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.6/dist-packages (from modAL) (1.4.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.6/dist-packages (from modAL) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18->modAL) (0.16.0)

# %%
#The core code for active learning. First we are making a training dataset from the pool of data we created in previous step.
#After that we depleted are pool intentionaly so that we can use this pool now as a test data set.
#Finally we used active learning with Random forest and KNN as its estimator. We trained it on the training data set we created earlier.
#Both of these trained models are finally appended in the list.

import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from modAL.models import ActiveLearner

n_members = 2
learner_list = list()

for member_idx in range(n_members):
    # initial training data
    n_initial = 2
    train_idx = np.random.choice(range(X_pool.shape[0]), size=n_initial, replace=False)
    X_train = X_pool[train_idx]
    y_train = y_pool[train_idx]

    # creating a reduced copy of the data with the known instances removed
    X_pool = np.delete(X_pool, train_idx, axis=0)
    y_pool = np.delete(y_pool, train_idx)

    # initializing learner
    if  (n_members == 0):               #Added this new code here.
      learner = ActiveLearner(estimator=RandomForestClassifier(), X_training=X_train, y_training=y_train)
    if  (n_members == 1):
      learner = ActiveLearner(estimator=KNeighborsClassifier(n_neighbors=2), X_training=X_train, y_training=y_train)
    learner_list.append(learner)

# %%
with plt.style.context('seaborn-white'):
    plt.figure(figsize=(n_members*7, 7))
    for learner_idx, learner in enumerate(learner_list):
        plt.subplot(1, n_members, learner_idx + 1)
        plt.scatter(x=pca[:, 0], y=pca[:, 1], c=learner.predict(breast_cancer['data']), cmap='viridis', s=50)
        plt.title('Learner no. %d initial predictions' % (learner_idx + 1))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-682ed77fed72> in <module>()
#       3     for learner_idx, learner in enumerate(learner_list):
#       4         plt.subplot(1, n_members, learner_idx + 1)
# ----> 5         plt.scatter(x=pca[:, 0], y=pca[:, 1], c=learner.predict(breast_cancer['data']), cmap='viridis', s=50)
#       6         plt.title('Learner no. %d initial predictions' % (learner_idx + 1))
#       7     plt.show()
#
# AttributeError: 'str' object has no attribute 'predict'

# %%
unqueried_score = learner.score(breast_cancer['data'], breast_cancer['target'])

with plt.style.context('seaborn-white'):
    plt.figure(figsize=(7, 7))
    prediction = learner.predict(breast_cancer['data'])
    plt.scatter(x=pca[:, 0], y=pca[:, 1], c=prediction, cmap='viridis', s=50)
    plt.title('learners initial predictions, accuracy = %1.3f' % unqueried_score)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1528462dceec> in <module>()
# ----> 1 unqueried_score = learner.score(breast_cancer['data'], breast_cancer['target'])
#       2
#       3 with plt.style.context('seaborn-white'):
#       4     plt.figure(figsize=(7, 7))
#       5     prediction = learner.predict(breast_cancer['data'])
#
# AttributeError: 'str' object has no attribute 'score'

# %%
predictions = learner.predict(X_pool)
is_correct = (predictions == y_pool)

predictions
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f265bcee968f> in <module>()
# ----> 1 predictions = learner.predict(X_pool)
#       2 is_correct = (predictions == y_pool)
#       3
#       4 predictions
#
# AttributeError: 'str' object has no attribute 'predict'

# %%
with plt.style.context('seaborn-white'):
    plt.figure(figsize=(n_members*7, 7))
    for learner_idx, learner in enumerate(learner_list):
        plt.subplot(1, n_members, learner_idx + 1)
        plt.scatter(x=pca[:, 0], y=pca[:, 1], c=learner.predict(breast_cancer['data']), cmap='viridis', s=50)
        plt.title('Learner no. %d predictions' % (learner_idx + 1))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-650275a3da2e> in <module>()
#       3     for learner_idx, learner in enumerate(learner_list):
#       4         plt.subplot(1, n_members, learner_idx + 1)
# ----> 5         plt.scatter(x=pca[:, 0], y=pca[:, 1], c=learner.predict(breast_cancer['data']), cmap='viridis', s=50)
#       6         plt.title('Learner no. %d predictions' % (learner_idx + 1))
#       7     plt.show()
#
# AttributeError: 'str' object has no attribute 'predict'

# %%
#Cross validation for KNN and Random Forest in active learner.

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import ShuffleSplit
from sklearn import metrics
from sklearn.model_selection import cross_val_score
cv = ShuffleSplit(n_splits=10, test_size=0.1, random_state=0)
score = cross_val_score(learner_list[0], X_pool, y_pool, cv=cv)
print("CV scores for Random Forest in active learner:\n", score)
score = cross_val_score(learner_list[1], X_pool, y_pool, cv=cv)
print("CV scores for KNN in active learner:\n", score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-5e9572cc4864> in <module>()
#       8 from sklearn.model_selection import cross_val_score
#       9 cv = ShuffleSplit(n_splits=10, test_size=0.1, random_state=0)
# ---> 10 score = cross_val_score(learner_list[0], X_pool, y_pool, cv=cv)
#      11 print("CV scores for Random Forest in active learner:\n", score)
#      12 score = cross_val_score(learner_list[1], X_pool, y_pool, cv=cv)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     381     """
#     382     # To ensure multimetric format is not supported
# --> 383     scorer = check_scoring(estimator, scoring=scoring)
#     384
#     385     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_scorer.py in check_scoring(estimator, scoring, allow_none)
#     399     if not hasattr(estimator, 'fit'):
#     400         raise TypeError("estimator should be an estimator implementing "
# --> 401                         "'fit' method, %r was passed" % estimator)
#     402     if isinstance(scoring, str):
#     403         return get_scorer(scoring)
#
# TypeError: estimator should be an estimator implementing 'fit' method, 'learner' was passed
